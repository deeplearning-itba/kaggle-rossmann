# %%
import pandas as pd
from pandas_summary import DataFrameSummary

# %% [markdown]
# # Competencia de Kaggle
#
# [ir a Kaggle](https://www.kaggle.com/c/rossmann-store-sales/data)
#
# [3er puesto](https://github.com/entron/entity-embedding-rossmann)

# %% [markdown]
# # Métrica de la competencia

# %% [markdown]
# $$
# \textrm{RMSE} = \sqrt{\frac{1}{n} \sum_{i=1}^{n} \left(\frac{\hat{y}_i - y_i}{y_i}\right)^2}
# $$
#
# donde:
#
# - $\hat{y}_i$ las ventas de un día particular de un store
# - $y_i$ ventas estimadas por el modelo
# - $n$ es el número de predicciones realizadas

# %% [markdown]
# ## Importamos dataset

# %% [markdown]
# La competencia permitía agregar datos externos para realizar la predicción

# %% [markdown]
# The following tables are available in the datasets:
#
# | Table        | Table Description| Origen de Datos|
# |--------------|--------------------------------------------------------------------|--|
# | train        | training set: información del store día a día, ventas, clientes, si es feriado, etc | Kaggle |
# | store        | Información general del store, por ejemplo datos del competidor | Kaggle |
# | store_states | Mapea de store a estado - Dato externo| Externos |
# | state_names  | Mapea estados a acronimo de estado | Externos |
# | googletrend  | Tendencias por semana - Dato externo| Externos|
# | weather      | Condiciones meteorológicas por día | Externos|

# %%
PATH = 'dataset/rossmann/'

# %%
table_names = ['train', 'store', 'store_states', 'state_names', 'googletrend', 'weather']
train, store, store_states, state_names, googletrend, weather = [pd.read_csv(PATH + fname+'.csv', 
                                                                             low_memory=False) for fname in table_names]

# %%
display(train.head())
display(DataFrameSummary(train).summary())
# Out:
#    Store  DayOfWeek        Date  Sales  Customers  Open  Promo StateHoliday  \
# 0      1          5  2015-07-31   5263        555     1      1            0
# 1      2          5  2015-07-31   6064        625     1      1            0
# 2      3          5  2015-07-31   8314        821     1      1            0
# 3      4          5  2015-07-31  13995       1498     1      1            0
# 4      5          5  2015-07-31   4822        559     1      1            0
#
#    SchoolHoliday
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1
#                     Store    DayOfWeek         Date        Sales    Customers  \
# count         1.01721e+06  1.01721e+06          NaN  1.01721e+06  1.01721e+06
# mean               558.43      3.99834          NaN      5773.82      633.146
# std               321.909      1.99739          NaN      3849.93      464.412
# min                     1            1          NaN            0            0
# 25%                   280            2          NaN         3727          405
# 50%                   558            4          NaN         5744          609
# 75%                   838            6          NaN         7856          837
# max                  1115            7          NaN        41551         7388
# counts            1017209      1017209      1017209      1017209      1017209
# uniques              1115            7          942        21734         4086
# missing                 0            0            0            0            0
# missing_perc           0%           0%           0%           0%           0%
# types             numeric      numeric  categorical      numeric      numeric
#
#                      Open        Promo StateHoliday SchoolHoliday
# count         1.01721e+06  1.01721e+06          NaN   1.01721e+06
# mean             0.830107     0.381515          NaN      0.178647
# std              0.375539     0.485759          NaN      0.383056
# min                     0            0          NaN             0
# 25%                     1            0          NaN             0
# 50%                     1            0          NaN             0
# 75%                     1            1          NaN             0
# max                     1            1          NaN             1
# counts            1017209      1017209      1017209       1017209
# uniques                 2            2            4             2
# missing                 0            0            0             0
# missing_perc           0%           0%           0%            0%
# types                bool         bool  categorical          bool

# %% [markdown]
# - Mirar counts que todos tienen la misma cantidad
# - Ninguno tiene missing
# - Los tipos tambien es interesante observar

# %%
train['StateHoliday'].value_counts()
# Out:
# 0    986159
# a     20260
# b      6690
# c      4100
# Name: StateHoliday, dtype: int64

# %%
display(store.head())
display(DataFrameSummary(store).summary())
# Out:
#    Store StoreType Assortment  CompetitionDistance  CompetitionOpenSinceMonth  \
# 0      1         c          a               1270.0                        9.0
# 1      2         a          a                570.0                       11.0
# 2      3         a          a              14130.0                       12.0
# 3      4         c          c                620.0                        9.0
# 4      5         a          a              29910.0                        4.0
#
#    CompetitionOpenSinceYear  Promo2  Promo2SinceWeek  Promo2SinceYear  \
# 0                    2008.0       0              NaN              NaN
# 1                    2007.0       1             13.0           2010.0
# 2                    2006.0       1             14.0           2011.0
# 3                    2009.0       0              NaN              NaN
# 4                    2015.0       0              NaN              NaN
#
#      PromoInterval
# 0              NaN
# 1  Jan,Apr,Jul,Oct
# 2  Jan,Apr,Jul,Oct
# 3              NaN
# 4              NaN
#                 Store    StoreType   Assortment CompetitionDistance  \
# count            1115          NaN          NaN                1112
# mean              558          NaN          NaN              5404.9
# std           322.017          NaN          NaN             7663.17
# min                 1          NaN          NaN                  20
# 25%             279.5          NaN          NaN               717.5
# 50%               558          NaN          NaN                2325
# 75%             836.5          NaN          NaN              6882.5
# max              1115          NaN          NaN               75860
# counts           1115         1115         1115                1112
# uniques          1115            4            3                 654
# missing             0            0            0                   3
# missing_perc       0%           0%           0%               0.27%
# types         numeric  categorical  categorical             numeric
#
#              CompetitionOpenSinceMonth CompetitionOpenSinceYear    Promo2  \
# count                              761                      761      1115
# mean                            7.2247                  2008.67  0.512108
# std                            3.21235                  6.19598  0.500078
# min                                  1                     1900         0
# 25%                                  4                     2006         0
# 50%                                  8                     2010         1
# 75%                                 10                     2013         1
# max                                 12                     2015         1
# counts                             761                      761      1115
# uniques                             12                       23         2
# missing                            354                      354         0
# missing_perc                    31.75%                   31.75%        0%
# types                          numeric                  numeric      bool
#
#              Promo2SinceWeek Promo2SinceYear PromoInterval
# count                    571             571           NaN
# mean                 23.5954         2011.76           NaN
# std                   14.142         1.67494           NaN
# min                        1            2009           NaN
# 25%                       13            2011           NaN
# 50%                       22            2012           NaN
# 75%                       37            2013           NaN
# max                       50            2015           NaN
# counts                   571             571           571
# uniques                   24               7             3
# missing                  544             544           544
# missing_perc          48.79%          48.79%        48.79%
# types                numeric         numeric   categorical

# %% [markdown]
# Descripción de algunas columnas que quizas no sean tan claras:
#
# - `Customers`: La cantidad de clientes por día
# - `Open`: Indicador si el store estaba abierto o cerrado: 0 = closed, 1 = open
# - `StateHoliday`: Indica feriado en ese estado. a = public holiday, b = Easter holiday, c = Christmas, 0 = None
# - `SchoolHoliday`: Inidica si el store fue afectado por el feriado escolar
# - `StoreType`: Tipos de store: a, b, c, d
# - `Assortment`: Describe el nivel de surtido de la tienda: a = basic, b = extra, c = extended
# - `CompetitionDistance`: Distancia en metros al competidor
# - `CompetitionOpenSince[Month/Year]`: Fecha en que abrío la competencia
# - `Promo`: Si el store esta corriendo una promoción ese día
# - `Promo2`: Promo2 is a continuing and consecutive promotion for some stores: 0 = store is not participating, 1 = store is participating
# - `Promo2Since[Year/Week]`: describes the year and calendar week when the store started participating in Promo2
# - `PromoInterval`: describes the consecutive intervals Promo2 is started, naming the months the promotion is started anew. E.g. "Feb,May,Aug,Nov" means each round starts in February, May, August, November of any given year for that store

# %%
store['StoreType'].value_counts()
# Out:
# a    602
# d    348
# c    148
# b     17
# Name: StoreType, dtype: int64

# %%
store['PromoInterval'].value_counts()
# Out:
# Jan,Apr,Jul,Oct     335
# Feb,May,Aug,Nov     130
# Mar,Jun,Sept,Dec    106
# Name: PromoInterval, dtype: int64

# %%
display(store_states.head())
display(DataFrameSummary(store_states).summary())
# Out:
#    Store State
# 0      1    HE
# 1      2    TH
# 2      3    NW
# 3      4    BE
# 4      5    SN
#                 Store        State
# count            1115          NaN
# mean              558          NaN
# std           322.017          NaN
# min                 1          NaN
# 25%             279.5          NaN
# 50%               558          NaN
# 75%             836.5          NaN
# max              1115          NaN
# counts           1115         1115
# uniques          1115           12
# missing             0            0
# missing_perc       0%           0%
# types         numeric  categorical

# %%
display(state_names.head())
display(DataFrameSummary(state_names).summary())
# Out:
#            StateName State
# 0  BadenWuerttemberg    BW
# 1             Bayern    BY
# 2             Berlin    BE
# 3        Brandenburg    BB
# 4             Bremen    HB
#              StateName   State
# count               16      16
# unique              16      16
# top           Saarland      ST
# freq                 1       1
# counts              16      16
# uniques             16      16
# missing              0       0
# missing_perc        0%      0%
# types           unique  unique

# %%
display(googletrend.head())
display(DataFrameSummary(googletrend).summary())
# Out:
#              file                     week  trend
# 0  Rossmann_DE_SN  2012-12-02 - 2012-12-08     96
# 1  Rossmann_DE_SN  2012-12-09 - 2012-12-15     95
# 2  Rossmann_DE_SN  2012-12-16 - 2012-12-22     91
# 3  Rossmann_DE_SN  2012-12-23 - 2012-12-29     48
# 4  Rossmann_DE_SN  2012-12-30 - 2013-01-05     67
#                      file         week    trend
# count                 NaN          NaN     2072
# mean                  NaN          NaN  63.8142
# std                   NaN          NaN  12.6502
# min                   NaN          NaN        0
# 25%                   NaN          NaN       55
# 50%                   NaN          NaN       64
# 75%                   NaN          NaN       72
# max                   NaN          NaN      100
# counts               2072         2072     2072
# uniques                14          148       68
# missing                 0            0        0
# missing_perc           0%           0%       0%
# types         categorical  categorical  numeric
